# %% [markdown]
# ### Matplotlib genomgång

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100) # 100 punkter mellan -5 till 5 
f = np. sin(x)

plt.figure(dpi = 100)
plt.plot(x, f)
plt.title("Sin(X)")
plt.xlabel("X")
plt.ylabel("X")
plt.show()

# %%
#imperativ approche 

fig, ax = plt.figure(dpi=100), plt.axes()

ax.plot(x, f)
ax.set(xlim = (-6, 6), ylim= (-1.5, 1.5), xlabel = "x", ylabel = "f", title = "sin(x)")
# Out:
# [(-6.0, 6.0),
#  (-1.5, 1.5),
#  Text(0.5, 0, 'x'),
#  Text(0, 0.5, 'f'),
#  Text(0.5, 1.0, 'sin(x)')]

# %%
# Subplots

plt.figure(figsize= (16, 5), dpi= 100)
plt.subplot(1, 2, 1)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.title("Plots")
plt.legend("sin(x), cos(x)")

plt.subplot(1, 2, 2)
plt.plot(x,np.cos(x))
plt.show()

# %%
fig, ax = plt.subplot(1, 2, dpi=150, figsize=(10, 4))

rnd = np.random.RandomState(seed=42) #Bra för att demonstrera med. 
#Man kan seeda sin slumpmässiga val, plockar en specifik slumpad sekvens som alltid är samma sekvens
data_normal_dist = rnd.rand(1000)

ax[0].hist(data_normal_dist, bins=30, alpha=0.5)
ax[0].set(titel="Histogram", xlabel="x", ylabel= "y")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 fig, ax = plt.subplot(1, 2, dpi=150, figsize=(10, 4))
#       3 rnd = np.random.RandomState(seed=42) #Bra för att demonstrera med. Man kan seeda sin slumpmässiga val
#       4 data_normal_dist = rnd.rand(1000)
#
# File c:\Users\User\Documents\Programering\Plugg AI\Python-programing-Hannes-Fredriksson-1\.venv\Lib\site-packages\matplotlib\pyplot.py:1534, in subplot(*args, **kwargs)
#    1531 fig = gcf()
#    1533 # First, search for an existing subplot with a matching spec.
# -> 1534 key = SubplotSpec._from_subplot_args(fig, args)
#    1536 for ax in fig.axes:
#    1537     # If we found an Axes at the position, we can reuse it if the user passed no
#    1538     # kwargs or if the Axes class and kwargs are identical.
#    1539     if (ax.get_subplotspec() == key
#    1540         and (kwargs == {}
# ...
