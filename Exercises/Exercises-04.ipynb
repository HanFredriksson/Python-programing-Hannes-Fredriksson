# %% [markdown]
# ## Svar på uppgifter för Excerises-04

# %% [markdown]
# ***Uppgift 1 Dice rolls***

# %%
import random as rnd

dice_rolls = ()
dice_rolls =[(rnd.randint(1, 6)) for roll in range(1, 11)]

print(f"Dice rolls: {dice_rolls}")

#A
dice_rolls.sort()
print(f"Sorted acending: {dice_rolls}")

#B
dice_rolls.sort(reverse= True)
print (f"Sorted decending: {dice_rolls}")

#C

print(f"Max value {max(dice_rolls)}")
print(f"Min value: {min(dice_rolls)}")
# Out:
# Dice rolls: [2, 6, 5, 2, 6, 1, 6, 3, 2, 6]
# Sorted acending: [1, 2, 2, 2, 3, 5, 6, 6, 6, 6]
# Sorted decending: [6, 6, 6, 6, 5, 3, 2, 2, 2, 1]
# Max value 6
# Min value: 1

# %% [markdown]
# ***Uppgift 2 Food menu***

# %%
dishes = ("vegetarisk lasagne", "spaghetti", "fisk", "grönsakssoppa", "pannkakor")
days = ("Mon", "Tue", "Wed", "Thu", "Fri")
menu = ""
for day, dish in zip(days, dishes):
    menu += f"{day} serving: {dish}\n"

print(menu)
# Out:
# Mon serving: vegetarisk lasagne
# Tue serving: spaghetti
# Wed serving: fisk
# Thu serving: grönsakssoppa
# Fri serving: pannkakor

# %% [markdown]
# ***Uppgift 3 Squares***

# %%
import matplotlib.pyplot as plt

squares = [square * square for square in range(-10, 11)]
print(squares)

y =  squares
x = [square for square in range(len(squares))]

plt.plot(x, y)
plt.title("Squares")
plt.xlabel("Square")
plt.ylabel("Itreation")
# Out:
# [100, 81, 64, 49, 36, 25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# Text(0, 0.5, 'Itreation')

# %% [markdown]
# ***Uppgift 4 Chessboard***

# %%
letters = ("ABCDEFGH")
number = 1
cordinates = [cordinate + str(number) for cordinate in letters]
print(f"{cordinates}\n")

cordinates_2d = [[cordinate + str(number) for cordinate in letters] for number in range(1, 9)]

for i in cordinates_2d:
    print(i)
# Out:
# ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']
#
# ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']
# ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2']
# ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3']
# ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4']
# ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5']
# ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6']
# ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7']
# ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8']

# %% [markdown]
# ***Uppgift 5 Dice rolls convergence***

# %%
import random as rnd
import matplotlib.pyplot as plt

#A
count_sixes = len([count for count in [rnd.randint(1, 6) for rolle in range(100)] if count == 6])
print(f"How many sixes in 100 roles: {count_sixes}")

#B
count_sixes_simulation = [len([count for count in [rnd.randint(1, 6) for rolle in range(10**rolled)] if count == 6])for rolled in range(1, 6)]
print(f"\nNumber of sixes rolled: {count_sixes_simulation}\n")

#C
probability = [sixes / 10**rolled for sixes, rolled in zip(count_sixes_simulation, range(1, 6))]
print (f"The probabilty of rolling a six: {probability}\n")

#C
num_rolls = (10, 100, 1000, 10000, 100000)
plt.plot(probability, '-*')
plt.title("Probability of six for different number of rolls")
plt.xticks([0,1,2,3,4], num_rolls);
plt.xlabel("Number of dice rolls")
plt.ylabel("Probability")
# Out:
# How many sixes in 100 roles: 15
#
# Number of sixes rolled: [0, 21, 184, 1625, 16611]
#
# The probabilty of rolling a six: [0.0, 0.21, 0.184, 0.1625, 0.16611]
# Text(0, 0.5, 'Probability')

# %% [markdown]
# ***Uppgift 6 Monto Carlo Simulation***

# %%
import numpy as np
import random as rnd
import matplotlib.pyplot as pl
197145911247, -0.5697287391563703, 0.8774884867199779, -0.12626685954818595, -0.26249705289611613, -0.40597179295058794, 0.5983604068635799, 0.20729537968420853, -0.47567529852733004, 0.13463744569027725, -0.9140740047560614, -0.3423191176275435, 0.6958617766077775, 0.6723759889755994, -0.6278798967485983, -0.28811578353986533, 0.3137067615239102, 0.0004244871607126388, 0.63755214536434, -0.035134295618380884, -0.41517865169128565, -0.2584370999529788, 0.5140463501222456, -0.680606243092001, 0.07946422590887092, -0.6159271876281303, 0.21499170916664467, -0.2320668419466172, -0.23420098377372, 0.6743917577061234, 0.9320187739071106, 0.5392639336419323, 0.024743029843180775, 0.09571714179987145, -0.6346086264031954, -0.11593251074468514, 0.33940130290786286, 0.40680972446888886, 0.0421597428736562, 0.5825314107272417, 0.6346817225362438, 0.02243381003603262, -0.032538928665927225, -0.09847047962825495, -0.3707731040425599, -0.7448775128934082, 0.16606729156784916, -0.4412253290992738, 0.37229203690058, 0.00047891029982816136, 0.673 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 34
#      23 #for xy in points_generator:
#      24  #   if euclidean(*xy):
#      25   #      euclidean_sort_blue_x.append(xy[0])
#    (...)
#      29      #   euclidean_sort_red_x.append(xy[0])
#      30       #  euclidean_sort_red_y.append(xy[1])
#      33 plt.scatter(euclidean_sort_red_x, euclidean_sort_red_y, c= "red")
# ---> 34 plt.scatter(euclidean_sort_blue_x, euclidean_sort_blue_y, c= "blue")
#      35 plt.show()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3903, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3884 @_copy_docstring_and_deprecators(Axes.scatter)
#    3885 def scatter(
#    3886     x: float | ArrayLike,
#    (...)
#    3901     **kwargs,
#    3902 ) -> PathCollection:
# -> 3903     __ret = gca().scatter(
#    3904         x,
#    3905         y,
#    3906         s=s,
#    3907         c=c,
#    3908         marker=marker,
#    3909         cmap=cmap,
#    3910         norm=norm,
#    3911         vmin=vmin,
#    3912         vmax=vmax,
#    3913         alpha=alpha,
#    3914         linewidths=linewidths,
#    3915         edgecolors=edgecolors,
#    3916         plotnonfinite=plotnonfinite,
#    3917         **({"data": data} if data is not None else {}),
#    3918         **kwargs,
#    3919     )
#    3920     sci(__ret)
#    3921     return __ret
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:4787, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4785 y = np.ma.ravel(y)
#    4786 if x.size != y.size:
# -> 4787     raise ValueError("x and y must be the same size")
#    4789 if s is None:
#    4790     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4791          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
import numpy as np
import random as rnd
import matplotlib.pyplot as plt 

def euclidean(x=1, y=2):
    distans = np.sqrt(np.square(x)+np.square(y))

    if distans < 1:
        return True
    else:
        return False

points_generator = [[rnd.uniform(-1.0, 1.0), rnd.uniform(-1.0, 1.0)] for simulations in range(5000)]

euclidean_sort_blue = []
euclidean_sort_red = []

for xy in points_generator:
    if euclidean(*xy):
        euclidean_sort_blue.append(xy)
        
    else:
        euclidean_sort_red.append(xy)

print(len(euclidean_sort_blue)/len(euclidean_sort_red))
# Out:
# 3.5004500450045004

# %% [markdown]
# ***Uppgif 7 A cute rabbit among two ferocious snakes***

# %% [markdown]
# ***#a***
#
# Svar: Jag står med mitt val och öppnar dörren jag valt. För sannolikheten för att det är en orm bakom dörren är lika stor, oavsett om jag byter eller inte.

# %%
import random as rnd
picked = 0
picked_switch = 0


for sim_stay in range(10):
    doors = [1, 2, 3]
    pick = rnd.choice(doors)
    rabbit = rnd.choice(doors)
    if pick == rabbit:
        picked += 1

for sim_switch in range(10):
    doors = [1, 2, 3]
    pick = rnd.choice(doors)
    rabbit = rnd.choice(doors)
    print(f"first pick {pick}")
    #print(f"after pick{doors}, \npick {pick}, \nrabbit {rabbit}")
    for door in doors:
        if door != pick and door != rabbit:
            doors.remove(door)
            break
    print(f"doors{doors}")
    
    pick = doors[0] if doors[0] != pick else doors[1]
    
    if pick == rabbit:
        picked_switch += 1

print(f"Second pick {pick}")
print(picked)
print(picked_switch)
# Out:
# first pick 2
# doors[2, 3]
# first pick 1
# doors[1, 2]
# first pick 1
# doors[1, 2]
# first pick 2
# doors[2, 3]
# first pick 3
# doors[1, 3]
# first pick 3
# doors[2, 3]
# first pick 1
# doors[1, 2]
# first pick 3
# doors[1, 3]
# first pick 1
# doors[1, 2]
# first pick 3
# doors[2, 3]
# Second pick 2
# 5
# 9
